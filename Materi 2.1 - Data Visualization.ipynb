# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv("./datasets/iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.isnull().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['species'].hist()
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind = 'scatter',
         x = 'sepal_length',
         y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot(kind = 'scatter',
         x = 'petal_length',
         y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# # Distribution plot

# %%
sns.distplot(iris['sepal_length'])
# Out:
# C:\Users\raris\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(iris['sepal_length'], bins =20)
# Out:
# C:\Users\raris\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.boxplot(data = iris)
plt.show()

# %%
sns.pairplot(data=iris)
plt.show()

# %%
sns.pairplot(data=iris, hue = 'species')
plt.show()

# %%
correlation = iris.corr()
correlation 
# korelasi antara tabel 1 dengan tabel lainny
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(correlation, annot = True) #Annot = Nilai korelasi
# Out:
# <AxesSubplot:>

# %%
movies = pd.read_csv('./datasets/types_movies.csv')
movies
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %%
plt.pie(movies['Percentage'], labels=movies['Sector'], autopct = '%.f%%')
plt.show()

# %%
st = pd.read_csv('./datasets/stocks.csv')
st
# Out:
#          Date        AAPL        ADBE         CVX        GOOG         IBM  \
# 0    3-Jan-07   11.107141   38.869999   50.777351  251.001007   79.242500
# 1    1-Feb-07   10.962033   39.250000   48.082939  224.949951   74.503204
# 2    1-Mar-07   12.037377   41.700001   51.900383  229.309311   75.561348
# 3    2-Apr-07   12.930043   41.560001   54.588032  235.925919   81.934280
# 4    1-May-07   15.701322   44.060001   57.598267  249.204208   85.786057
# ..        ...         ...         ...         ...         ...         ...
# 116  1-Sep-16  111.987015  108.540001  100.933739  804.059998  156.186905
# 117  3-Oct-16  112.472404  107.510002  102.728424  809.900024  151.113403
# 118  1-Nov-16  110.042900  102.809998  110.502274  775.880005  160.947403
# 119  1-Dec-16  115.320023  102.949997  116.584061  792.450012  164.687836
# 120  3-Jan-17  121.104935  113.820000  110.759811  823.830017  174.420883
#
#           MDLZ       MSFT        NFLX       ORCL       SBUX
# ...

# %%
st['Date']=pd.to_datetime(st['Date'])
st
# Out:
#           Date        AAPL        ADBE         CVX        GOOG         IBM  \
# 0   2007-01-03   11.107141   38.869999   50.777351  251.001007   79.242500
# 1   2007-02-01   10.962033   39.250000   48.082939  224.949951   74.503204
# 2   2007-03-01   12.037377   41.700001   51.900383  229.309311   75.561348
# 3   2007-04-02   12.930043   41.560001   54.588032  235.925919   81.934280
# 4   2007-05-01   15.701322   44.060001   57.598267  249.204208   85.786057
# ..         ...         ...         ...         ...         ...         ...
# 116 2016-09-01  111.987015  108.540001  100.933739  804.059998  156.186905
# 117 2016-10-03  112.472404  107.510002  102.728424  809.900024  151.113403
# 118 2016-11-01  110.042900  102.809998  110.502274  775.880005  160.947403
# 119 2016-12-01  115.320023  102.949997  116.584061  792.450012  164.687836
# 120 2017-01-03  121.104935  113.820000  110.759811  823.830017  174.420883
#
#           MDLZ       MSFT        NFLX       ORCL       SBUX
# ...

# %%
fig, ax = plt.subplots(figsize = (10,10))

ax.plot(st['Date'],
       st['AAPL'])

plt.show()

# %%
fig= plt.figure(figsize = (10,10))

ax1 = fig.add_subplot(231)

ax1.plot(st['Date'],
       st['AAPL'],
        color = 'g'
        )
ax1.set_title = ('AAPL')


ax2 = fig.add_subplot(232)

ax2.plot(st['Date'],
       st['ADBE'],
        color = 'r'
        )
ax2.set_title = ('ADBE')


ax3 = fig.add_subplot(233)

ax3.plot(st['Date'],
       st['GOOG'],
        color = 'b'
        )
ax3.set_title = ('GOOG')


ax4 = fig.add_subplot(234)

ax4.plot(st['Date'],
       st['NFLX'],
        color = 'magenta'
        )
ax4.set_title = ('NFLX')

ax5 = fig.add_subplot(235)

ax5.plot(st['Date'],
       st['IBM'],
        color = 'orange'
        )
ax5.set_title = ('IBM')


ax6 = fig.add_subplot(236)

ax6.plot(st['Date'],
       st['ORCL'],
        color = 'k'
        )
ax6.set_title = ('ORCL')

plt.show()

# %%
fig= plt.figure(figsize = (20,10))

ax1 = fig.add_subplot(231)

ax1.plot(st['Date'],
       st['AAPL'],
        color = 'g'
        )
ax1.set_title = ('AAPL')


ax2 = fig.add_subplot(232)

ax2.plot(st['Date'],
       st['ADBE'],
        color = 'r'
        )
ax2.set_title = ('ADBE')


ax3 = fig.add_subplot(233)

ax3.plot(st['Date'],
       st['GOOG'],
        color = 'b'
        )
ax3.set_title = ('GOOG')


ax4 = fig.add_subplot(234)

ax4.plot(st['Date'],
       st['NFLX'],
        color = 'magenta'
        )
ax4.set_title = ('NFLX')

ax5 = fig.add_subplot(235)

ax5.plot(st['Date'],
       st['IBM'],
        color = 'orange'
        )
ax5.set_title = ('IBM')


ax6 = fig.add_subplot(236)

ax6.plot(st['Date'],
       st['ORCL'],
        color = 'k'
        )
ax6.set_title = ('ORCL')

plt.show()

# %%
cc=pd.read_csv('./datasets/countries.csv')
cc
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
dt_2007 = cc[cc['year']==2007]
dt_2007
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 11           Afghanistan      Asia  2007          43.828    31889923
# 23               Albania    Europe  2007          76.423     3600523
# 35               Algeria    Africa  2007          72.301    33333216
# 47                Angola    Africa  2007          42.731    12420476
# 59             Argentina  Americas  2007          75.320    40301927
# ...                  ...       ...   ...             ...         ...
# 1655             Vietnam      Asia  2007          74.249    85262356
# 1667  West Bank and Gaza      Asia  2007          73.422     4018332
# 1679         Yemen, Rep.      Asia  2007          62.698    22211743
# 1691              Zambia    Africa  2007          42.384    11746035
# 1703            Zimbabwe    Africa  2007          43.487    12311143
#
#       gdpPerCapita
# 11      974.580338
# 23     5937.029526
# 35     6223.367465
# 47     4797.231267
# 59    12779.379640
# ...

# %%
top_10 = dt_2007.sort_values('population', ascending=False).head(10)
top_10
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 299           China      Asia  2007          72.961  1318683096   4959.114854
# 707           India      Asia  2007          64.698  1110396331   2452.210407
# 1619  United States  Americas  2007          78.242   301139947  42951.653090
# 719       Indonesia      Asia  2007          70.650   223547000   3540.651564
# 179          Brazil  Americas  2007          72.390   190010647   9065.800825
# 1175       Pakistan      Asia  2007          65.483   169270617   2605.947580
# 107      Bangladesh      Asia  2007          64.062   150448339   1391.253792
# 1139        Nigeria    Africa  2007          46.859   135031164   2013.977305
# 803           Japan      Asia  2007          82.603   127467972  31656.068060
# 995          Mexico  Americas  2007          76.195   108700891  11977.574960

# %%
fig, ax = plt.subplots(figsize = (15,8))

r=range(10)

ax.bar(r, top_10['population'])
plt.xticks(r, top_10['country'])

plt.show()
